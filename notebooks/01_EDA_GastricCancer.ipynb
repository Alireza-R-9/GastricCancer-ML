# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/Users/m2/Documents/code/Meta-Gastric-Classifier/data/gastric.csv') 
df.head()
# Out:
#    Age   BMI  Hemoglobin  Glucose  Protein     WBC   RBC   BP   Fat Diagnosis
# 0   33  19.1        10.3    142.0      5.7  6554.0  3.61  134  15.7   Healthy
# 1   68  32.4        12.6    128.0      7.9  7607.0  4.45  109  26.6    Cancer
# 2   44  31.6        11.8    124.0      8.1  4615.0  5.32  136  23.0    Cancer
# 3   42  25.6        13.3    145.0      6.1  9960.0  5.80  135  24.8   Healthy
# 4   36  31.4        10.3    109.0      5.6  8792.0  4.12  118  24.2    Cancer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         253 non-null    int64
#  1   BMI         253 non-null    float64
#  2   Hemoglobin  253 non-null    float64
#  3   Glucose     253 non-null    float64
#  4   Protein     253 non-null    float64
#  5   WBC         253 non-null    float64
#  6   RBC         253 non-null    float64
#  7   BP          253 non-null    int64
#  8   Fat         253 non-null    float64
#  9   Diagnosis   253 non-null    object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 19.9+ KB

# %%
df.describe()
# Out:
#               Age         BMI  Hemoglobin     Glucose     Protein  \
# count  253.000000  253.000000  253.000000  253.000000  253.000000
# mean    54.802372   26.605929   13.441502  116.699605    6.970751
# std     14.810458    5.065805    1.973932   24.902123    0.829906
# min     30.000000   18.000000   10.000000   71.000000    5.500000
# 25%     42.000000   22.200000   11.800000   97.000000    6.300000
# 50%     54.000000   26.800000   13.400000  119.000000    6.900000
# 75%     68.000000   31.100000   15.000000  136.000000    7.700000
# max     79.000000   35.000000   17.000000  160.000000    8.500000
#
#                 WBC         RBC          BP         Fat
# count    253.000000  253.000000  253.000000  253.000000
# mean    7387.426877    4.730158  119.786561   25.101581
# std     1958.880207    0.730692   17.636821    8.839791
# min     4002.000000    3.530000   90.000000   10.200000
# 25%     5629.000000    4.070000  106.000000   17.400000
# 50%     7488.000000    4.730000  120.000000   25.600000
# 75%     9029.000000    5.370000  136.000000   32.800000
# max    10981.000000    5.990000  149.000000   39.700000

# %%
df.isnull().sum()
# Out:
# Age           0
# BMI           0
# Hemoglobin    0
# Glucose       0
# Protein       0
# WBC           0
# RBC           0
# BP            0
# Fat           0
# Diagnosis     0
# dtype: int64

# %%
sns.countplot(x='Diagnosis', data=df, palette='Set2')
plt.title('Class Distribution')
plt.show()
# Out:
# /var/folders/s5/9nvctw0d6rgcb7ys2twd1ynw0000gn/T/ipykernel_35125/3789843935.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Diagnosis', data=df, palette='Set2')

# %%
df.hist(bins=20, figsize=(15, 10), color='skyblue', edgecolor='black')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.drop('Diagnosis', axis=1).corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
